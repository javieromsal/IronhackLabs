# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100

# %%
df = pd.read_csv('Data_Marketing_Customer_Analysis_Round3.csv')

# %%
df
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688      central                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   region                         10689 non-null  object
#  1   customer_lifetime_value        10689 non-null  int64
#  2   response                       10689 non-null  object
#  3   coverage                       10689 non-null  object
#  4   education                      10689 non-null  object
#  5   effective_to_date              10689 non-null  object
#  6   month                          10689 non-null  object
#  7   employment_status              10689 non-null  object
#  8   gender                         10689 non-null  object
#  9   income                         10689 non-null  int64
#  10  location_code                  10689 non-null  object
#  11  marital_status                 10689 non-null  object
# ...

# %% [markdown]
# ## Create a Data frame with numerical columns

# %%
numerical = df.select_dtypes(include='number')
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %%
numerical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_lifetime_value        10689 non-null  int64
#  1   income                         10689 non-null  int64
#  2   monthly_premium_auto           10689 non-null  int64
#  3   months_since_last_claim        10689 non-null  int64
#  4   months_since_policy_inception  10689 non-null  int64
#  5   number_of_open_complaints      10689 non-null  int64
#  6   number_of_policies             10689 non-null  int64
#  7   total_claim_amount             10689 non-null  int64
# dtypes: int64(8)
# memory usage: 668.2 KB

# %%
numerical.describe().T
# Out:
#                                  count          mean           std      min  \
# customer_lifetime_value        10689.0   8011.906727   6877.557889   1898.0
# income                         10689.0  51750.243989  24778.053035  10037.0
# monthly_premium_auto           10689.0     93.190196     34.413111     61.0
# months_since_last_claim        10689.0     15.144073     10.086110      0.0
# months_since_policy_inception  10689.0     48.100571     27.934300      0.0
# number_of_open_complaints      10689.0      0.384975      0.910210      0.0
# number_of_policies             10689.0      2.980821      2.399497      1.0
# total_claim_amount             10689.0    434.227243    292.550878      0.0
#
#                                    25%      50%      75%      max
# customer_lifetime_value         4014.0   5776.0   8991.0  83325.0
# income                         29335.0  50398.0  72131.0  99981.0
# monthly_premium_auto              68.0     83.0    109.0    298.0
# ...

# %% [markdown]
# ## Create a Data frame with categorical values

# %%
categorical = df.select_dtypes(exclude='number')
categorical.info()
categorical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   region             10689 non-null  object
#  1   response           10689 non-null  object
#  2   coverage           10689 non-null  object
#  3   education          10689 non-null  object
#  4   effective_to_date  10689 non-null  object
#  5   month              10689 non-null  object
#  6   employment_status  10689 non-null  object
#  7   gender             10689 non-null  object
#  8   location_code      10689 non-null  object
#  9   marital_status     10689 non-null  object
#  10  policy_type        10689 non-null  object
#  11  policy             10689 non-null  object
#  12  renew_offer_type   10689 non-null  object
#  13  sales_channel      10689 non-null  object
#  14  vehicle_class      10689 non-null  object
#  15  vehicle_size       10689 non-null  object
# ...

# %% [markdown]
# # Check the normality of the numerical variables visually

# %% [markdown]
# ### Use seaborn library to construct distribution plots for the numerical variables

# %%
numerical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_lifetime_value        10689 non-null  int64
#  1   income                         10689 non-null  int64
#  2   monthly_premium_auto           10689 non-null  int64
#  3   months_since_last_claim        10689 non-null  int64
#  4   months_since_policy_inception  10689 non-null  int64
#  5   number_of_open_complaints      10689 non-null  int64
#  6   number_of_policies             10689 non-null  int64
#  7   total_claim_amount             10689 non-null  int64
# dtypes: int64(8)
# memory usage: 668.2 KB

# %%
for col in numerical.columns:
    sns.displot(numerical[col])

# %%
fig=plt.figure(figsize=(10,5))
#ax=fig.add_subplot(2,2,2)
#ax1=fig.add_subplot(2,2,1)
numerical['income'].hist(bins=20,ax=fig.add_subplot(1,2,2),facecolor='blue')
numerical['number_of_policies'].hist(bins=20,ax=fig.add_subplot(1,2,1),facecolor='blue')
# Out:
# <AxesSubplot:>

# %%
def histograms_plot(dataframe, columns, rows, cols):
    fig=plt.figure(figsize=(20,20))
    for i, columns in enumerate(columns):
        ax=fig.add_subplot(rows,cols,i+1)
        dataframe[columns].hist(bins=20,ax=ax,facecolor='blue')
        ax.set_title('Histogram of '+columns,color='black')

fig.tight_layout()  
plt.show()

# %%
histograms_plot(numerical,numerical.columns,4,2)

# %%
plt.subplots(figsize=(14, 20))
count=1
for i in numerical.columns:
    plt.subplot(4,2,count)
    sns.distplot(numerical[i])
    count+=1
plt.show()
# Out:
# C:\Users\javie\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\javie\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## Correlation Heatmap

# %%
x = numerical.drop(['total_claim_amount'],axis=1)
fig=plt.figure(figsize=(8,5))
sns.heatmap(numerical.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Activity 4

# %%
categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   region             10689 non-null  object
#  1   response           10689 non-null  object
#  2   coverage           10689 non-null  object
#  3   education          10689 non-null  object
#  4   effective_to_date  10689 non-null  object
#  5   month              10689 non-null  object
#  6   employment_status  10689 non-null  object
#  7   gender             10689 non-null  object
#  8   location_code      10689 non-null  object
#  9   marital_status     10689 non-null  object
#  10  policy_type        10689 non-null  object
#  11  policy             10689 non-null  object
#  12  renew_offer_type   10689 non-null  object
#  13  sales_channel      10689 non-null  object
#  14  vehicle_class      10689 non-null  object
#  15  vehicle_size       10689 non-null  object
# ...

# %% [markdown]
# ### Show a plot of the total number of responses.

# %%
categorical["response"].value_counts()
# Out:
# no     9316
# yes    1373
# Name: response, dtype: int64

# %%
responses =categorical["response"].value_counts()

# %%
responses
# Out:
# no     9316
# yes    1373
# Name: response, dtype: int64

# %%
plt.bar(responses.index, responses, color=('red','green'))
plt.title('Total number of responses', fontweight='bold')
plt.ylabel("# responses")
# Out:
# Text(0, 0.5, '# responses')

# %% [markdown]
# ### Show a plot of the response by the sales channel.

# %%
responses_by_sales = categorical.groupby(['sales_channel','response'])["response"].count().rename('count').reset_index()

# %%
responses_by_sales
# Out:
#   sales_channel response  count
# 0         agent       no   3340
# 1         agent      yes    679
# 2        branch       no   2665
# 3        branch      yes    310
# 4   call center       no   1890
# 5   call center      yes    209
# 6           web       no   1421
# 7           web      yes    175

# %%
x,y=responses_by_sales['sales_channel'],responses_by_sales['count']
hue=responses_by_sales['response']

# %%
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
plt.title('Response by sales channel', size='25', fontweight='bold')

sns.barplot(x ,y , hue = hue)
# Out:
# C:\Users\javie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Response by sales channel'}, xlabel='sales_channel', ylabel='count'>

# %% [markdown]
# ### Response by total claim amount.

# %%
# pd.cut to segment and sort data values into bins. 
df['claim_cat'] = pd.cut(df['total_claim_amount'], bins=[0, 200, 400, 600,800,1000, float('Inf')],
                         labels=['0-200', '200-400', '400-600','600-800','800-1000','>1000'])
# float('inf') It acts as an unbounded upper value for comparison

# %%
df.head()
# Out:
#         region  customer_lifetime_value response  coverage education  \
# 0      central                     4809       no     basic   college
# 1  west region                     2228       no     basic   college
# 2         east                    14947       no     basic  bachelor
# 3   north west                    22332      yes  extended   college
# 4   north west                     9025       no   premium  bachelor
#
#   effective_to_date month employment_status gender  income  ...  \
# 0           2/18/11   feb          employed      m   48029  ...
# 1           1/18/11   jan        unemployed      f   92260  ...
# 2           2/10/11   feb          employed      m   22139  ...
# 3           1/11/11   jan          employed      m   49078  ...
# 4           1/17/11   jan     medical leave      f   23675  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                         0                  9  corporate auto  corporate l3
# ...

# %%
responses_by_claim=df.groupby(['claim_cat','response'])["response"].count().rename('count').reset_index()
responses_by_claim
# Out:
#    claim_cat response  count
# 0      0-200       no   1833
# 1      0-200      yes    165
# 2    200-400       no   3111
# 3    200-400      yes    497
# 4    400-600       no   2485
# 5    400-600      yes    479
# 6    600-800       no    992
# 7    600-800      yes    140
# 8   800-1000       no    474
# 9   800-1000      yes     29
# 10     >1000       no    412
# 11     >1000      yes     63

# %%
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
plt.title('Response by total claim amount', size='25', fontweight='bold')
sns.barplot(x = responses_by_claim['claim_cat'],\
            y = responses_by_claim['count'], hue = responses_by_claim['response']);

# %% [markdown]
# ### Response by income

# %%
 df['income_cat'] = pd.cut(df['income'], bins=[0, 20000, 40000, 60000,80000,100000],
                         labels=['<20,000', '<40,000', '<60,000','<80,000','<100,000'])
# float('inf') It acts as an unbounded upper value for comparison

# %%
responses_by_income=df.groupby(['income_cat','response'])["response"].count().rename('count').reset_index()
responses_by_income
# Out:
#   income_cat response  count
# 0    <20,000       no    743
# 1    <20,000      yes    186
# 2    <40,000       no   2738
# 3    <40,000      yes    469
# 4    <60,000       no   2143
# 5    <60,000      yes    262
# 6    <80,000       no   2043
# 7    <80,000      yes    287
# 8   <100,000       no   1649
# 9   <100,000      yes    169

# %%
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
plt.title('Response by income', size='25', fontweight='bold')
sns.barplot(x = responses_by_income['income_cat'],\
            y = responses_by_income['count'], hue = responses_by_income['response']);

# %% [markdown]
# # Target variable: "total_claim_amount"

# %% [markdown]
# **Business Objectives:**
#
# -Retain customers
#
# -analyze relevant customer data
#
# -develop focused customer retention programs

# %%
sns.displot(df['total_claim_amount'])

# %%
sns.boxplot(x="total_claim_amount",data=df)
# Out:
# <AxesSubplot:xlabel='total_claim_amount'>

# %%
claims =df.groupby(['claim_cat'])["total_claim_amount"].sum().rename('sum').reset_index()
claims
# Out:
#   claim_cat      sum
# 0     0-200   195980
# 1   200-400  1132273
# 2   400-600  1463458
# 3   600-800   773867
# 4  800-1000   447333
# 5     >1000   628544

# %%
x,y=claims['claim_cat'],claims['sum']
sns.barplot(x, y)
plt.title('Total number of responses', fontweight='bold')
plt.ylabel("claim amount")
# Out:
# C:\Users\javie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'claim amount')

# %% [markdown]
# ## Numerical variables X's vs Y plotting

# %%
plt.subplots(figsize=(30, 100));
count=1
for i in numerical:
    plt.subplot(9,2,count);
    sns.histplot(numerical[i]);
    plt.subplot(9,2,count+1);
    sns.regplot(x=numerical[i],y=numerical.total_claim_amount);
    count+=2
plt.show();

# %%
df.groupby(['region'])["total_claim_amount"].mean().rename('claim_mean').reset_index()
# Out:
#         region  claim_mean
# 0      central  428.979486
# 1         east  438.018299
# 2   north west  432.978745
# 3  west region  438.673464

# %% [markdown]
# **From the above charts we can conclude that:**
#
# 1.- cutomer_lifetime_value
#
# 2.- monthly_premium_auto
#
# **Are the only numerical variables that seems to be related with a change in the target valriable**

# %% [markdown]
# ## Categorical variables X's vs Y plotting

# %%
plt.subplots(figsize=(20, 40))
count=1
for i in df:
    if df[i].dtypes == object:
        temp=df.groupby([i])["total_claim_amount"].mean().rename('mean').reset_index()
        plt.subplot(9,2,count)
        sns.barplot(x = temp[i],\
            y = temp['mean']);
        count+=1
plt.show()

# %% [markdown]
# **For the categorical variables we can conclude that:**
# 1. coverage
# 2. location_code
# 3. vehicle_class
#
# **are related with a change on total_claim mean**
